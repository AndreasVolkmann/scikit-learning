# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv("http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv")

# %%
cols = ["TV", "Radio", "Newspaper"]
sns.pairplot(data, x_vars=cols, y_vars="Sales", size=7, aspect=0.7)
